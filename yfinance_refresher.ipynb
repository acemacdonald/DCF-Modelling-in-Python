# %% [markdown]
# # Using the Yahoo Finance Library
#
# In this notebook I run through some of the basic functions and use cases for using the yahoo finance library.
#
# This will be helpful for then building a financial model within Python.

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %% [markdown]
# To download the stock data of a particular company, we can specify the ticker and use the following command:

# %%
aapl_df = yf.download('AAPL')

aapl_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099450
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094261
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087343
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089504
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092099
# ...                ...         ...         ...         ...         ...
# 2023-10-31  169.350006  170.899994  167.899994  170.770004  170.770004
# 2023-11-01  171.000000  174.229996  170.119995  173.970001  173.970001
# 2023-11-02  175.520004  177.779999  175.460007  177.570007  177.570007
# 2023-11-03  174.240005  176.820007  173.350006  176.649994  176.649994
# 2023-11-06  176.380005  179.429993  176.210007  179.229996  179.229996
#
#                Volume
# Date
# ...

# %% [markdown]
# You can tweak this by defining for how many periods you want in your dataset, as well as plotting the time-series.

# %%
ticker = yf.Ticker('AAPL')
aapl_df = ticker.history(period="5y")
aapl_df['Close'].plot(title="APPLE's stock price")
# Out:
# <Axes: title={'center': "APPLE's stock price"}, xlabel='Date'>

# %% [markdown]
# You can grab some of the core information, such as actions, dividends and stock splits:

# %%
aapl_df = yf.Ticker("AAPL")

aapl_df.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0
# ...                              ...           ...
# 2022-08-05 00:00:00-04:00   0.230000           0.0
# 2022-11-04 00:00:00-04:00   0.230000           0.0
# 2023-02-10 00:00:00-05:00   0.230000           0.0
# 2023-05-12 00:00:00-04:00   0.240000           0.0
# 2023-08-11 00:00:00-04:00   0.240000           0.0
#
# [85 rows x 2 columns]

# %%
aapl_df.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# Name: Dividends, Length: 80, dtype: float64

# %%
aapl_df.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# You can even retrive information such as the majority shareholders of Apple stock.

# %%
aapl_df.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  61.32%       % of Shares Held by Institutions
# 2  61.36%        % of Float Held by Institutions
# 3    5762  Number of Institutions Holding Shares

# %%
aapl_df.financials
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.147192
# Normalized EBITDA                                   125820000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              125820000000.0
# EBIT                                                114301000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %%
aapl_df.balance_sheet
# Out:
#                                                         2023-09-30  \
# Treasury Shares Number                                         0.0
# Ordinary Shares Number                               15550061000.0
# Share Issued                                         15550061000.0
# Net Debt                                             81123000000.0
# Total Debt                                          111088000000.0
# Tangible Book Value                                  62146000000.0
# Invested Capital                                    173234000000.0
# Working Capital                                      -1742000000.0
# Net Tangible Assets                                  62146000000.0
# Common Stock Equity                                  62146000000.0
# Total Capitalization                                157427000000.0
# Total Equity Gross Minority Interest                 62146000000.0
# Stockholders Equity                                  62146000000.0
# ...

# %% [markdown]
# What we really want if the aim is to build financial statements is to store these in separate datasets, this can be done by simply defining the ticker as a variable, then specifying which statement you are looking for.

# %%
ticker = 'AAPL'

bal_sheet = yf.Ticker("AAPL").balance_sheet
inc_statement = yf.Ticker("AAPL").income_stmt
cf_statement = yf.Ticker("AAPL").cash_flow

# %% [markdown]
# Then if we want to look at our balance sheet in the latest year, we can quickly define the years by passing the amount of columns and then calling the function on the latest year.

# %%
years = bal_sheet.columns

bal_sheet[years[0:1]]
# Out:
#                                                         2023-09-30
# Treasury Shares Number                                         0.0
# Ordinary Shares Number                               15550061000.0
# Share Issued                                         15550061000.0
# Net Debt                                             81123000000.0
# Total Debt                                          111088000000.0
# Tangible Book Value                                  62146000000.0
# Invested Capital                                    173234000000.0
# Working Capital                                      -1742000000.0
# Net Tangible Assets                                  62146000000.0
# Common Stock Equity                                  62146000000.0
# Total Capitalization                                157427000000.0
# Total Equity Gross Minority Interest                 62146000000.0
# Stockholders Equity                                  62146000000.0
# ...

# %% [markdown]
# Let's say we want to look at the last 3 years of the income statement, then we can similarly call the function to return our data.

# %%
years = inc_statement.columns

inc_statement[years[0:3]]
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.147192
# Normalized EBITDA                                   125820000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              125820000000.0
# EBIT                                                114301000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %% [markdown]
# ## Summary & Next Steps

# %% [markdown]
# At this stage it must be noted that the data is not structured in a way that normal financial data is structured. For our purpose, we are more concerned with getting the financial statements and using the data to correctly model our financials.
